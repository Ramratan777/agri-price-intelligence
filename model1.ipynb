# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("crop_yield.csv")

# %%
data.shape
# Out:
# (1000000, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Region                  1000000 non-null  object
#  1   Soil_Type               1000000 non-null  object
#  2   Crop                    1000000 non-null  object
#  3   Rainfall_mm             1000000 non-null  float64
#  4   Temperature_Celsius     1000000 non-null  float64
#  5   Fertilizer_Used         1000000 non-null  bool
#  6   Irrigation_Used         1000000 non-null  bool
#  7   Weather_Condition       1000000 non-null  object
#  8   Days_to_Harvest         1000000 non-null  int64
#  9   Yield_tons_per_hectare  1000000 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 62.9+ MB

# %%
data.isnull().sum()
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %%
data.describe()
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
import seaborn as sns
sns.pairplot(data)

# %%
sns.scatterplot(x="Rainfall_mm",y="Yield_tons_per_hectare",data=data)
# Out:
# <Axes: xlabel='Rainfall_mm', ylabel='Yield_tons_per_hectare'>

# %%
sns.scatterplot(x="Temperature_Celsius",y="Yield_tons_per_hectare",data=data)
# Out:
# <Axes: xlabel='Temperature_Celsius', ylabel='Yield_tons_per_hectare'>

# %%
sampled_data = data.sample(n=10000, random_state=42)

# %%
sampled_data.shape
# Out:
# (10000, 10)

# %%
sns.scatterplot(x="Rainfall_mm",y="Yield_tons_per_hectare",data=sampled_data)
# Out:
# <Axes: xlabel='Rainfall_mm', ylabel='Yield_tons_per_hectare'>

# %%
sns.scatterplot(x="Temperature_Celsius",y="Yield_tons_per_hectare",data=sampled_data)
# Out:
# <Axes: xlabel='Temperature_Celsius', ylabel='Yield_tons_per_hectare'>

# %%
sampled_data.sample()
# Out:
#        Region Soil_Type   Crop  Rainfall_mm  Temperature_Celsius  \
# 221579  South     Sandy  Maize   130.803526            36.231766
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 221579            False            False             Sunny              119
#
#         Yield_tons_per_hectare
# 221579                1.273287

# %%
df=sampled_data

# %%
df["Region"].value_counts()
# Out:
# Region
# South    2511
# West     2510
# North    2492
# East     2487
# Name: count, dtype: int64

# %%
df["Soil_Type"].value_counts()
# Out:
# Soil_Type
# Loam      1697
# Peaty     1681
# Clay      1676
# Sandy     1663
# Chalky    1647
# Silt      1636
# Name: count, dtype: int64

# %%
plt.hist(df["Yield_tons_per_hectare"], bins=30)
# Out:
# (array([  6.,  13.,  41.,  72., 124., 181., 242., 300., 419., 455., 522.,
#         570., 627., 701., 656., 721., 697., 663., 582., 527., 463., 374.,
#         341., 225., 170., 143.,  95.,  50.,  14.,   6.]),
#  array([-0.18965889,  0.13161893,  0.45289674,  0.77417455,  1.09545237,
#          1.41673018,  1.738008  ,  2.05928581,  2.38056362,  2.70184144,
#          3.02311925,  3.34439707,  3.66567488,  3.9869527 ,  4.30823051,
#          4.62950832,  4.95078614,  5.27206395,  5.59334177,  5.91461958,
#          6.23589739,  6.55717521,  6.87845302,  7.19973084,  7.52100865,
#          7.84228646,  8.16356428,  8.48484209,  8.80611991,  9.12739772,
#          9.44867554]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df["Rainfall_mm"], bins=30)
# Out:
# (array([338., 353., 307., 338., 314., 336., 329., 320., 337., 330., 323.,
#         322., 317., 354., 350., 342., 334., 333., 351., 342., 331., 347.,
#         308., 333., 346., 347., 326., 312., 314., 366.]),
#  array([100.4181454 , 130.39926976, 160.38039413, 190.36151849,
#         220.34264286, 250.32376722, 280.30489159, 310.28601595,
#         340.26714032, 370.24826468, 400.22938905, 430.21051341,
#         460.19163778, 490.17276214, 520.15388651, 550.13501087,
#         580.11613524, 610.0972596 , 640.07838397, 670.05950834,
#         700.0406327 , 730.02175707, 760.00288143, 789.9840058 ,
#         819.96513016, 849.94625453, 879.92737889, 909.90850326,
#         939.88962762, 969.87075199, 999.85187635]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df["Temperature_Celsius"], bins=30)
# Out:
# (array([320., 376., 331., 328., 310., 352., 320., 343., 353., 320., 317.,
#         338., 302., 348., 351., 309., 334., 358., 309., 339., 351., 356.,
#         315., 324., 334., 333., 327., 324., 343., 335.]),
#  array([15.00643119, 15.83940489, 16.67237859, 17.50535228, 18.33832598,
#         19.17129968, 20.00427338, 20.83724708, 21.67022078, 22.50319448,
#         23.33616818, 24.16914188, 25.00211558, 25.83508928, 26.66806298,
#         27.50103668, 28.33401038, 29.16698408, 29.99995777, 30.83293147,
#         31.66590517, 32.49887887, 33.33185257, 34.16482627, 34.99779997,
#         35.83077367, 36.66374737, 37.49672107, 38.32969477, 39.16266847,
#         39.99564217]),
#  <BarContainer object of 30 artists>)

# %%
df["Weather_Condition"].value_counts()
# Out:
# Weather_Condition
# Cloudy    3382
# Rainy     3328
# Sunny     3290
# Name: count, dtype: int64

# %%
plt.hist(df["Days_to_Harvest"], bins=30)
# Out:
# (array([344., 327., 328., 318., 350., 334., 340., 304., 322., 328., 345.,
#         314., 310., 343., 342., 326., 334., 333., 342., 357., 310., 341.,
#         367., 337., 334., 358., 325., 306., 333., 348.]),
#  array([ 60.        ,  62.96666667,  65.93333333,  68.9       ,
#          71.86666667,  74.83333333,  77.8       ,  80.76666667,
#          83.73333333,  86.7       ,  89.66666667,  92.63333333,
#          95.6       ,  98.56666667, 101.53333333, 104.5       ,
#         107.46666667, 110.43333333, 113.4       , 116.36666667,
#         119.33333333, 122.3       , 125.26666667, 128.23333333,
#         131.2       , 134.16666667, 137.13333333, 140.1       ,
#         143.06666667, 146.03333333, 149.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.displot(df["Yield_tons_per_hectare"], kde=True)

# %%
df["Crop"].value_counts()
# Out:
# Crop
# Soybean    1720
# Cotton     1700
# Rice       1681
# Barley     1668
# Maize      1616
# Wheat      1615
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

# %%
df.sample()
# Out:
#        Region Soil_Type   Crop  Rainfall_mm  Temperature_Celsius  \
# 366975  South      Loam  Maize   450.424551            27.429034
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 366975            False            False             Rainy               71
#
#         Yield_tons_per_hectare
# 366975                3.413795

# %%
# Out:
# pandas.core.series.Series

# %%
x_train,x_test, y_train, y_test = train_test_split(df.drop(['Yield_tons_per_hectare'], axis=1), df['Yield_tons_per_hectare'], test_size=0.2, random_state=42)

# %%
trf1=ColumnTransformer([('imputing', SimpleImputer(strategy='most_frequent'), [0,1,2,3,4,5,6,7,8])], remainder='passthrough')

# %%
trf2=ColumnTransformer([('scaling', MinMaxScaler(), [3,4,8])], remainder='passthrough')

# %%
trf3=ColumnTransformer([('encoding', OneHotEncoder(handle_unknown='ignore', sparse_output=False), [3,4,5,8])], remainder='passthrough')

# %%
pipeline=Pipeline([('imputing', trf1), ('scaling', trf2), ('encoding', trf3)])

# %%
trf4=ColumnTransformer([('pca', PCA(n_components=5), list(range(df.shape[1])))], remainder='passthrough')

# %%
lr = LinearRegression()

# %%
full_pipeline=Pipeline([('preprocessing', pipeline), ('pca', trf4), ('model', lr)])

# %%
full_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputing',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('imputing',
#                                                                    SimpleImputer(strategy='most_frequent'),
#                                                                    [0, 1, 2, 3,
#                                                                     4, 5, 6, 7,
#                                                                     8])])),
#                                  ('scaling',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('scaling',
#                                                                    MinMaxScaler(),
#                                                                    [3, 4,
# ...

# %%
y_pred=full_pipeline.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9160154656961311

# %%
print(x_train.columns.tolist())
print(new_data.columns.tolist())
# Out:
# ['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius', 'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition', 'Days_to_Harvest']
# ['Region', 'Soil_type', 'Crop', 'Rainfall_mm', 'Temperature_celsius', 'Fertilizer_used', 'Irrigation_used', 'Weather_condition', 'Days_to_harvest']

# %%
new_data = pd.DataFrame({
    'Region': ['South'],
    'Soil_Type': ['Silt'],
    'Crop': ['Maize'],
    'Rainfall_mm': [280],
    'Temperature_Celsius': [36],
    'Fertilizer_Used': [True],
    'Irrigation_Used': [False],
    'Weather_Condition': ['Sunny'],
    'Days_to_Harvest': [140]
})

prediction = full_pipeline.predict(new_data)

print("Predicted Yield:", prediction[0])
# Out:
# Predicted Yield: 3.6085921076733154

# %%
data.shape
# Out:
# (1000000, 10)

# %%
next=data[10003:10004]
next
# Out:
#       Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 10003  South    Chalky  Cotton   663.963252            32.210454
#
#        Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 10003             True             True            Cloudy              111
#
#        Yield_tons_per_hectare
# 10003                6.043278

# %%
preediction = full_pipeline.predict(next)

# %%
prediction
# Out:
# array([3.60859211])

# %%
data['Yield_tons_per_hectare'].mean()
# Out:
# np.float64(4.649472487663023)
